# %% [markdown]
#  # CSE-ADARSH KASULA-221710305046

# %% [markdown]
# ## Question 1:
# ```Import the required packages
# please mention in comment for which purpose you are using the package```

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Question 2:
# ```Print version of each packages you have imported```

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
np.__version__
# Out:
# '1.16.5'

# %% [markdown]
# ## Question 3:
# ```read the data using pandas
# store it in variable df```

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sumathi16/Datasets/master/upvotes.csv")
df
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0
#
# [330045 rows x 7 columns]

# %% [markdown]
# ## Question 4:
# ```Understanding the data
# How many rows are there in the data?
# How many columns are there?
# How many categorical columns are there?
# Print the categorical column names
# Print the numerical column names```

# %%
df.shape[0] ##Rows present
# Out:
# 330045

# %%
df.shape[1] #Columns present
# Out:
# 7

# %%
cat_col=df.columns[df.dtypes=='category']
cat_col
# Out:
# Index([], dtype='object')

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head() #printing the categorical data
# Out:
#   Tag
# 0   a
# 1   a
# 2   c
# 3   a
# 4   c

# %%
obj_df1 = df.select_dtypes(include=['integer','float']).copy()
obj_df1.head()
# Out:
#        ID  Reputation  Answers  Username    Views  Upvotes
# 0   52664      3942.0      2.0    155623   7855.0     42.0
# 1  327662     26046.0     12.0     21781  55801.0   1175.0
# 2  468453      1358.0      4.0     56177   8067.0     60.0
# 3   96996       264.0      3.0    168793  27064.0      9.0
# 4  131465      4271.0      4.0    112223  13986.0     83.0

# %%
df2=df.select_dtypes(include=['object'])
df2
# Out:
#        Tag
# 0        a
# 1        a
# 2        c
# 3        a
# 4        c
# ...     ..
# 330040   c
# 330041   c
# 330042   c
# 330043   j
# 330044   j
#
# [330045 rows x 1 columns]

# %%
df2.shape[1] #number of columns
# Out:
# 1

# %% [markdown]
# # Question 6:
#
# ```draw a relplot by palcing views on y and upvotes on x¶
# draw the plot using data argument
# draw the plot without using data argument```

# %%
sns.relplot("Views","Upvotes",data=df,color="red")## with data argument

# %%
sns.relplot
# Out:
# <function seaborn.relational.relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)>

# %% [markdown]
# # Question 7:
# ```Add another argument for hue the above plot.
# check it with one numerical column as hue
# check it with one categorical column as hue```

# %%
sns.relplot("Views","Upvotes",data=df,color="blue",hue="ID") # with one numerical column

# %%
sns.relplot("Views","Upvotes",data=df,color="blue",hue="Tag")

# %%
df['Tag'].unique()
# Out:
# array(['a', 'c', 'r', 'j', 'p', 's', 'h', 'o', 'i', 'x'], dtype=object)

# %% [markdown]
# ## Question 8
# ```Modify the above plot using any of the parameters size,style,col```

# %%
sns.relplot("Views","Upvotes",data=df,col="Tag",hue="ID")

# %% [markdown]
# ## Question 9:
# ```Draw the cat plot by taking tag on xaxis and upvotes on yaxis```

# %%
sns.catplot("Tag","Upvotes",data=df)

# %%
sns.catplot("Tag",data=df,kind="count") #Draw the suitable plot to display How many questions are there for each Tag

# %%
# Draw the suitable plot which will provide estimated line fit for the Answers and Upvotes

# %%
sns.regplot("Answers","Upvotes",data=df)

# %%
# Draw the boxplot for all the numerical columns

# %%
num_col=df.columns[df.dtypes!='object']
for col in num_col:
    sns.boxplot(col,data=df)
    plt.show()

# %%
# Observe the distribution of all the numerical columns

# %%
for col in num_col:
    sns.distplot(df[col],hist=True,kde=False)
    plt.show()

# %%
# Draw a pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# ```Create a new column with name 'Ans' using Answers column in the df.
# make the values which are 0 as Unanswered
# make the values which are in 1-20 range as 'Twenty'
# make the values which are in 21-40 range as 'Forty'
# make the values which are in 41-60 range as 'Sixty'
# make the values which are in 61-80 range as 'Eighty'
# Here You are creating a categorical column from numerical ccolumn```

# %%
labels=['Unanswered','Twenty','Forty', 'Sixty', 'Eighty']
bins=[0,1,21,41,61,81]
df['Ans']=pd.cut(df.Answers,bins,labels=labels,include_lowest=True)

df
# Out:
#             ID Tag  Reputation  Answers  Username    Views  Upvotes     Ans
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0  Twenty
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0  Twenty
# 2       468453   c      1358.0      4.0     56177   8067.0     60.0  Twenty
# 3        96996   a       264.0      3.0    168793  27064.0      9.0  Twenty
# 4       131465   c      4271.0      4.0    112223  13986.0     83.0  Twenty
# ...        ...  ..         ...      ...       ...      ...      ...     ...
# 330040  339800   c        36.0      2.0     84919   1063.0      0.0  Twenty
# 330041  253800   c      1649.0      2.0     76730  23319.0     73.0  Twenty
# 330042  210756   c      6178.0      2.0     91701   2453.0     15.0  Twenty
# 330043   56089   j        89.0      2.0     80245   2107.0      3.0  Twenty
# 330044  300553   j      2001.0      4.0    154692   2554.0     37.0  Twenty
#
# [330045 rows x 8 columns]

# %% [markdown]
# ```Draw a boxplot by taking Ans column on Xaxis and Upvotes on Y axis
# try this with boxplot
# try this with catplot```

# %%
sns.catplot("Ans","Upvotes",data=df)

# %%
sns.boxplot("Ans","Upvotes",data=df)

# %%
sns.catplot("Ans","Upvotes",data=df,kind="box")

# %%
## Caluculate the correlation among all the possible numerical columns. Represnt those values using a suitable graph

# %%
df.corr()
# Out:
#                   ID  Reputation   Answers  Username     Views   Upvotes
# ID          1.000000    0.008546  0.017448  0.000628  0.017400  0.006328
# Reputation  0.008546    1.000000  0.066504 -0.041019  0.036455  0.266710
# Answers     0.017448    0.066504  1.000000 -0.012197  0.498642  0.202033
# Username    0.000628   -0.041019 -0.012197  1.000000  0.002306 -0.011970
# Views       0.017400    0.036455  0.498642  0.002306  1.000000  0.437336
# Upvotes     0.006328    0.266710  0.202033 -0.011970  0.437336  1.000000

# %%
# heatmap corelation

# %%
sns.heatmap(df.corr())

# %%
df_tag1=df[df["Tag"]=='a']
print("unique values",df_tag1["Tag"].unique())
df_tag1
# Out:
# unique values ['a']
#             ID Tag  Reputation  Answers  Username    Views  Upvotes  \
# 0        52664   a      3942.0      2.0    155623   7855.0     42.0
# 1       327662   a     26046.0     12.0     21781  55801.0   1175.0
# 3        96996   a       264.0      3.0    168793  27064.0      9.0
# 30      106895   a       347.0      3.0    154557  22195.0      8.0
# 33      292364   a      9051.0      2.0     58930  46305.0    363.0
# ...        ...  ..         ...      ...       ...      ...      ...
# 330018  343134   a      4503.0      6.0    169019  26688.0    140.0
# 330023  410941   a        28.0      5.0     99082   6004.0     10.0
# 330030  202255   a       476.0      3.0    106383  11537.0     13.0
# 330031  106211   a      1836.0      1.0      8874   4010.0     12.0
# 330034  468835   a      3165.0     15.0     98736  63005.0    422.0
#
#                Ans
# 0           Twenty
# 1           Twenty
# 3           Twenty
# 30          Twenty
# 33          Twenty
# ...            ...
# 330018      Twenty
# 330023      Twenty
# 330030      Twenty
# 330031  Unanswered
# 330034      Twenty
#
# [31695 rows x 8 columns]

# %%
# With the dataframe(df_tag1) try any three plots We discussed either in matplotlib or seaborn

# %%
sns.relplot("Upvotes","Views",data=df_tag1)

# %%
sns.catplot("Upvotes","Views",data=df_tag1)

# %%
sns.pairplot(df_tag1)
